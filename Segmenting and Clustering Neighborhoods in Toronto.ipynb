# %%
import numpy as np
import pandas as pd

# %%
html_data = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
table=html_data[0]
column_names = ['PostalCode', 'Borough', 'Neighborhood'] 
neighborhoods = pd.DataFrame(columns=column_names)
rowm,colm = table.shape
table.head()
# Out:
#                                                    0                1  \
# 0                                    M1ANot assigned  M2ANot assigned
# 1                    M1BScarborough(Malvern / Rouge)  M2BNot assigned
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...  M2CNot assigned
# 3  M1EScarborough(Guildwood / Morningside / West ...  M2ENot assigned
# 4                             M1GScarborough(Woburn)  M2GNot assigned
#
#                                                 2  \
# 0                        M3ANorth York(Parkwoods)
# 1                   M3BNorth York(Don Mills)North
# 2  M3CNorth York(Don Mills)South(Flemingdon Park)
# 3                                 M3ENot assigned
# 4                                 M3GNot assigned
#
#                                                 3  \
# 0                 M4ANorth York(Victoria Village)
# 1  M4BEast York(Parkview Hill / Woodbine Gardens)
# 2                  M4CEast York(Woodbine Heights)
# ...

# %%
L1=[]
for i in range(rowm):
    for j in range(colm):
        i=table.iloc[0,0][0:3]
        L.append(i)
neighborhoods=pd.DataFrame(L,columns=['PostalCode'])
neighborhoods
# Out:
#     PostalCode
# 0          M1A
# 1          M1A
# 2          M1A
# 3          M1A
# 4          M1A
# ..         ...
# 175        M1A
# 176        M1A
# 177        M1A
# 178        M1A
# 179        M1A
#
# [180 rows x 1 columns]

# %%
# Out:
#   File "<ipython-input-53-5a88c17b5f12>", line 1
#     for i,j in range(10)
#                         ^
# SyntaxError: invalid syntax
